# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle

# %%
# loading the insurance dataset 
insurance_df = pd.read_csv('insurance-2.csv')
insurance_df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# checking for nan values
insurance_df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# checking for duplicates
duplicates = insurance_df.duplicated(keep = 'first').sum()
print(f'There  are {duplicates} duplicates')
# Out:
# There  are 1 duplicates

# %%
# dropping duplicates
insurance_df = insurance_df.drop_duplicates(keep = 'first')

# %%
insurance_df.shape
# Out:
# (1337, 7)

# %%
# checkig for the unique values in the region column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
# converting the values in the region column to numerical 
insurance_df['region'] = insurance_df['region'].map(
    {'southwest': 1, 'southeast': 2, 'northwest': 3, 'northeast': 4})

# %%
insurance_df
# Out:
#       age     sex   bmi  children smoker  region  expenses
# 0      19  female  27.9         0    yes       1  16884.92
# 1      18    male  33.8         1     no       2   1725.55
# 2      28    male  33.0         3     no       2   4449.46
# 3      33    male  22.7         0     no       3  21984.47
# 4      32    male  28.9         0     no       3   3866.86
# ...   ...     ...   ...       ...    ...     ...       ...
# 1333   50    male  31.0         3     no       3  10600.55
# 1334   18  female  31.9         0     no       4   2205.98
# 1335   18  female  36.9         0     no       2   1629.83
# 1336   21  female  25.8         0     no       1   2007.95
# 1337   61  female  29.1         0    yes       3  29141.36
#
# [1337 rows x 7 columns]

# %%
# converting the values in the sex column to numerical 
insurance_df['sex'] = insurance_df['sex'].map(
    {'male': 0, 'female': 1})
insurance_df['sex']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    1
# 1335    1
# 1336    1
# 1337    1
# Name: sex, Length: 1337, dtype: int64

# %%
#converting the values in the smoker column to numerical
label_encoder = LabelEncoder()
insurance_df['smoker'] = label_encoder.fit_transform(insurance_df['smoker'])
insurance_df['smoker']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1337, dtype: int64

# %% [markdown]
# Defining a function that checks for outliers in a column, given a df and a column

# %%
# using boxplot to check for outliers

def checking_outliers(df, column):
    outliers = sns.boxplot(x = df[column])
    return outliers

# %%
# checking for ouytliers in the expenses column
checking_outliers(insurance_df, 'expenses')
plt.show()

# %% [markdown]
# The insurance dataset now looks clean abd we can now train and test our model and use it to predict.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
insurance_df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# expenses    float64
# dtype: object

# %%
# finding the correlations
relationship = insurance_df.corr()
relationship
# Out:
#                age       sex       bmi  children    smoker    region  expenses
# age       1.000000  0.019814  0.109414  0.041536 -0.025587 -0.001626  0.298308
# sex       0.019814  1.000000 -0.046405 -0.017848 -0.076596  0.004936 -0.058045
# bmi       0.109414 -0.046405  1.000000  0.012641  0.003964 -0.157448  0.198637
# children  0.041536 -0.017848  0.012641  1.000000  0.007331 -0.016258  0.067389
# smoker   -0.025587 -0.076596  0.003964  0.007331  1.000000  0.002358  0.787234
# region   -0.001626  0.004936 -0.157448 -0.016258  0.002358  1.000000  0.006547
# expenses  0.298308 -0.058045  0.198637  0.067389  0.787234  0.006547  1.000000

# %%
# visualizing the correlation
sns.heatmap(relationship, annot = True)
plt.show()

# %%
# dropping columns that less affect expenses
insurance_df = insurance_df.drop(columns = (['sex','children', 'region']))
insurance_df
# Out:
#       age   bmi  smoker  expenses
# 0      19  27.9       1  16884.92
# 1      18  33.8       0   1725.55
# 2      28  33.0       0   4449.46
# 3      33  22.7       0  21984.47
# 4      32  28.9       0   3866.86
# ...   ...   ...     ...       ...
# 1333   50  31.0       0  10600.55
# 1334   18  31.9       0   2205.98
# 1335   18  36.9       0   1629.83
# 1336   21  25.8       0   2007.95
# 1337   61  29.1       1  29141.36
#
# [1337 rows x 4 columns]

# %%
# checking for the maximum and minimum values for expenses columns
insurance_df['expenses'].max()
insurance_df['expenses'].min()
# Out:
# 1121.87

# %%
# feature matrix and the target vector
x = insurance_df.drop('expenses', axis=1)
y = insurance_df['expenses']

# %%
# splitting the insurance dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state=42 )

# %%
# intiatializing the model
multi_model = LinearRegression()

# %%
# fitting the model
multi_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# predicting the expenses using the tyest set
y_pred = multi_model.predict(x_test)

# %%
# calculating the performance metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 35843744.09023381
# R-squared: 0.8049384470255434

# %%
# plotting the actual vs the predicted values
plt. figure(figsize=(10,6))
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--k')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted expenses')
plt.show()

# %%
# Residuals plot
residuals = y_test - y_pred
plt.figure(figsize=(10,6))
plt.scatter(y_pred, residuals)
plt.hlines(y=0, xmin=y_pred.min(), xmax=y_pred.max(), colors='red', linestyles='--')
plt.xlabel('Predicted')
plt.ylabel('Residuals')
plt.title('Residuals of Predictions')
plt.show()

# %% [markdown]
# Based on the r2 score, the MSE and how the residuals are scattered around the horizontal line the model is performing well.

# %%
# saving the trained model to a file using pickle(serilization)

with open('multi_model.pkl', 'wb') as multimodel_file:
    pickle.dump(multi_model, multimodel_file)
